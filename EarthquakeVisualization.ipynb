# %%
# Name: Jacob Basabe
# Dataset: Global Earthquake Data
# chose this dataset because it contains real-world earthquake data from around the globe I thought it was interesting hiw much data can be gathered
# about earthquakes

# Import libraries
import pandas as pd

# Dataset URL
url = "https://raw.githubusercontent.com/plotly/datasets/master/earthquakes-23k.csv"

# Read dataset into a Pandas DataFrame
df = pd.read_csv(url)

# Display the first 5 rows of the dataset
df.head()
# Out:
#          Date  Latitude  Longitude  Magnitude
# 0  01/02/1965    19.246    145.616        6.0
# 1  01/04/1965     1.863    127.352        5.8
# 2  01/05/1965   -20.579   -173.972        6.2
# 3  01/08/1965   -59.076    -23.557        5.8
# 4  01/09/1965    11.938    126.427        5.8

# %%
# Summary statistics of the dataset
df.describe()
# Out:
#            Latitude     Longitude     Magnitude
# count  23412.000000  23412.000000  23412.000000
# mean       1.679033     39.639961      5.882531
# std       30.113183    125.511959      0.423066
# min      -77.080000   -179.997000      5.500000
# 25%      -18.653000    -76.349750      5.600000
# 50%       -3.568500    103.982000      5.700000
# 75%       26.190750    145.026250      6.000000
# max       86.005000    179.998000      9.100000

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
url = "https://raw.githubusercontent.com/plotly/datasets/master/earthquakes-23k.csv"
df = pd.read_csv(url)

# create histogram
plt.figure(figsize=(10,6))
sns.histplot(df["Magnitude"], bins=30, kde=True)

plt.title("Distribution of Earthquake Magnitudes")
plt.xlabel("Magnitude")
plt.ylabel("Frequency")

plt.show()

# description
print("This histogram shows how earthquake magnitudes are distributed. Most earthquakes are low magnitude, while high-magnitude earthquakes are rare. This is important because it highlights how uncommon but potentially dangerous large earthquakes are.")
# Out:
# This histogram shows how earthquake magnitudes are distributed. Most earthquakes are low magnitude, while high-magnitude earthquakes are rare. This is important because it highlights how uncommon but potentially dangerous large earthquakes are.
